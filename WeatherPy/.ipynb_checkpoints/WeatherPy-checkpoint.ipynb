# %% [markdown]
# # WeatherPy
#
# ---

# %%
#Import Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
#pip install citipy

# %%
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generating the cities List by using citipy

# %%
#List for latitudes and longitudes
lat_lngs = []
cities = []

#Ranges of lat and lon
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

#merge the lats and lngs lists into one list 
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 578

# %%
cities
#try list
#cities2=[cities[0],cities[1],cities[2]]
#cities2
# Out:
# ['adamstown',
#  'puerto natales',
#  'nola',
#  'kodiak',
#  'waitangi',
#  'punta arenas',
#  'port-aux-francais',
#  'jamestown',
#  'edinburgh of the seven seas',
#  'invercargill',
#  'petropavlovsk-kamchatsky',
#  'enewetak',
#  'puerto ayora',
#  'port mathurin',
#  'remire-montjoly',
#  'klyuchi',
#  'longyearbyen',
#  'pachino',
#  'albany',
#  'sandnessjoen',
#  'talnakh',
#  'nogliki',
#  'grytviken',
#  'atafu village',
#  'vanimo',
#  'smithers',
#  'bethel',
#  'sellersburg',
#  'san patricio',
#  'blackmans bay',
#  'katima mulilo',
#  'rimouski',
#  'kristiansund',
#  'cabedelo',
#  'arvika',
#  'chinchilla',
#  'bredasdorp',
#  'dawei',
#  'amahai',
#  'porto novo',
#  'ushuaia',
#  'pisco',
#  'tahe',
#  'ciudad lazaro cardenas',
#  'avarua',
#  'trat',
#  'el bauga',
#  'pandan',
#  'yellowknife',
#  'ust-nera',
#  'dampit',
#  'huetamo de nunez',
#  'taiohae',
#  'margaret river',
#  'wakkanai',
#  "port saint john's",
#  'saipan',
#  'tolanaro',
#  'mount pearl',
#  'puerto aysen',
#  'leiston',
#  'nyurba',
#  'alice springs',
#  'kachug',
#  'weno',
#  'kourou',
#  'east london',
#  'stanley',
#  'dudinka',
#  'garoowe',
#  'shubarkuduk',
#  'keflavik',
#  'revda',
#  'zemio',
#  'yuzhno-kurilsk',
#  'hithadhoo',
#  'papatowai',
#  'carnarvon',
#  'forster',
#  'santa cruz',
#  'olovyannaya',
#  'udachny',
#  'begamganj',
#  'anadyr',
#  'hawaiian paradise park',
#  'happy valley-goose bay',
#  'georgetown',
#  'cochrane',
#  'villa mercedes',
#  'ribeira grande',
#  'zaraza',
#  'howrah',
#  'mejit',
#  'hobyo',
#  'linxia chengguanzhen',
#  'hafar al-batin',
#  'touros',
#  'karkira',
#  'bardai',
#  'susuman',
#  'ouellah',
#  'cargados carajos',
#  'iqaluit',
#  'kone',
#  'ugoofaaru',
#  'miyanoura',
#  'port dickson',
#  'kannangad',
#  'port lincoln',
#  'sungailiat',
#  'road town',
#  'wailua homesteads',
#  'wynyard',
#  'bilibino',
#  'shanwei',
#  'ilulissat',
#  'whitehorse',
#  'polyarnyy',
#  'puerto san carlos',
#  'ko pha ngan',
#  'tiksi',
#  'new norfolk',
#  'grand falls-windsor',
#  'kresek',
#  'sitka',
#  'kuqa',
#  'alotau',
#  'borgarnes',
#  'isafjordur',
#  'temiskaming shores',
#  "'ohonua",
#  "pont-l'abbe",
#  'gazojak',
#  'codrington',
#  'vorgashor',
#  'murzuq',
#  'itoman',
#  'namsos',
#  'nouadhibou',
#  "mek'ele",
#  'ancud',
#  'san juan de miraflores',
#  'concordia',
#  'kingston',
#  'nova vicosa',
#  'guerrero negro',
#  'rumoi',
#  'san antonio de pale',
#  'castillos',
#  'olonkinbyen',
#  'qaqortoq',
#  'broken hill',
#  'port alfred',
#  'afaahiti',
#  'vadso',
#  'devinuwara',
#  'as sulayyil',
#  'west island',
#  'malango',
#  'flying fish cove',
#  'villarrobledo',
#  "ust'-kut",
#  'taiobeiras',
#  'vernon',
#  'caleta de carquin',
#  'camana',
#  'severo-yeniseyskiy',
#  'luderitz',
#  'oamaru',
#  'ibotirama',
#  'igrim',
#  'faya-largeau',
#  'bargaal',
#  'badger',
#  'sao gabriel da cachoeira',
#  'wenxing',
#  'mount isa',
#  'semnan',
#  'pimentel',
#  'kuching',
#  'freetown',
#  'yreka',
#  'micheweni',
#  'isle of lewis',
#  'barah',
#  'noumea',
#  'levuka',
#  'piacabucu',
#  'mpika',
#  'queenstown',
#  'belmonte',
#  'praia da vitoria',
#  'sultanah',
#  'puerto baquerizo moreno',
#  'vila velha',
#  'hermanus',
#  'buta',
#  'myrina',
#  'inirida',
#  'margate',
#  'melekeok village',
#  'oodweyne',
#  'lihue',
#  'skovorodino',
#  'north bend',
#  'malita',
#  'constitucion',
#  'gaspe',
#  'fale old settlement',
#  'puerto colombia',
#  'yarmouth',
#  'thompson',
#  'salalah',
#  'kalmunai',
#  'neryungri',
#  'dryden',
#  'toga village',
#  'benguela',
#  'verkhnevilyuysk',
#  'roccella ionica',
#  'aykhal',
#  'yorkton',
#  'anqing',
#  'yeniseysk',
#  'timoteo',
#  'buka',
#  'arraial do cabo',
#  'casino',
#  'lebu',
#  'chiredzi',
#  'kodinsk',
#  'ciudad bolivar',
#  'hamilton',
#  'ulladulla',
#  "la'ie",
#  'lensk',
#  "novyy turtkul'",
#  'kuloy',
#  'lejanias',
#  'qarazhal',
#  'ceeldheer',
#  'nordhausen',
#  'kindu',
#  'tarko-sale',
#  'tazacorte',
#  'bijie',
#  'xindi',
#  'bulungu',
#  'cumaribo',
#  'zaozhuang',
#  'jamaame',
#  'ouarzazat',
#  'port elizabeth',
#  'knokke',
#  'yonggwang-up',
#  'utrik',
#  'auki',
#  "kapa'a",
#  'chifeng',
#  'cable beach',
#  'hammerfest',
#  'tynda',
#  "ytyk-kyuyel'",
#  'fuxin',
#  'port-vila',
#  'thunder bay',
#  'jiaojiang',
#  'cortez',
#  'kerikeri',
#  'valparaiso',
#  'tura',
#  'selfoss',
#  'dumai',
#  'kerema',
#  'calama',
#  'umag',
#  'inhambane',
#  'zaragoza',
#  'isiolo',
#  'akureyri',
#  'nacozari de garcia',
#  'negombo',
#  'fort pierce',
#  'robertsport',
#  'katsuura',
#  'saint-pierre',
#  'fomboni',
#  'novyy urengoy',
#  'carutapera',
#  'sinabang',
#  'al hilaliyya',
#  'fort st. john',
#  'fuvahmulah',
#  'erdenet',
#  'landeck',
#  'sur',
#  'rawson',
#  'kidal',
#  'sandikli',
#  'skowhegan',
#  'mizdah',
#  'tabuk',
#  'canutama',
#  'esfarayen',
#  'rampachodavaram',
#  'reggane',
#  "val-d'or",
#  'ekibastuz',
#  'sechenovo',
#  'fort morgan',
#  'porto murtinho',
#  'wainwright',
#  'puerto cabezas',
#  "st. john's",
#  'mahajanga',
#  'rethymno',
#  'dalbandin',
#  'cabo san lucas',
#  'talara',
#  'palikir - national government center',
#  'argo',
#  'uturoa',
#  'sassandra',
#  'khorixas',
#  'nishinoomote',
#  'correntina',
#  'commentry',
#  'plettenberg bay',
#  'traralgon',
#  'chela',
#  'haenam',
#  'oranjemund',
#  'parkersburg',
#  'carauari',
#  'butterworth',
#  'rio grande',
#  'kaifeng',
#  'shalqar',
#  'kampene',
#  'aasiaat',
#  'sierra grande',
#  'villa gesell',
#  'rawai',
#  'baluntaicun',
#  "ust'-talovka",
#  'minot',
#  'mili',
#  'dingwall',
#  'astrakhan',
#  'dalandzadgad',
#  'kankaanpaa',
#  'namibe',
#  'kargasok',
#  'yerofey pavlovich',
#  'nyandoma',
#  'dien bien phu',
#  'sao jose da coroa grande',
#  'coahuayana de hidalgo',
#  'solnechnyy',
#  'al kharijah',
#  'filadelfia',
#  'guatrache',
#  'saint-francois',
#  'penafiel',
#  'gebeit',
#  'tranovaho',
#  'san jose village',
#  'picos',
#  'khandyga',
#  'popondetta',
#  'panghyon-dong',
#  'vilyuchinsk',
#  'anibare',
#  'male',
#  'yokadouma',
#  'juan griego',
#  'quezon',
#  'tralee',
#  'champerico',
#  'saint-philippe',
#  'coquimbo',
#  'usogorsk',
#  'viedma',
#  'rakops',
#  'chonchi',
#  'lompoc',
#  'butwal',
#  'portland',
#  'kolobrzeg',
#  'govindgarh',
#  'minab',
#  'ola',
#  'college',
#  'markovo',
#  'hotan',
#  'konstantinovka',
#  'kiuruvesi',
#  'ghat',
#  'kokologo',
#  'miguel ahumada',
#  'pitiquito',
#  'arafat',
#  'al jawf',
#  'urucara',
#  'pathein',
#  'santa croce camerina',
#  'egilsstadir',
#  'shklow',
#  'alofi',
#  'hirara',
#  'hargeysa',
#  'smara',
#  'burnie',
#  'saurimo',
#  'phnom penh',
#  'mhangura',
#  'suva',
#  'sinhyeon',
#  'shahrak',
#  'isangel',
#  'ta`u',
#  'colonia',
#  'chernomorskoye',
#  'aberdeen',
#  'jacksonville',
#  'inhumas',
#  'westport',
#  'dongola',
#  'pacific grove',
#  'tongchuanshi',
#  'kultali',
#  'minas de marcona',
#  'san julian',
#  'palmer',
#  'howard springs',
#  'bayanhongor',
#  'saldanha',
#  'la sarre',
#  'semey',
#  'port douglas',
#  'hadibu',
#  'lazaro cardenas',
#  'takamaka',
#  "baykal'sk",
#  'kill devil hills',
#  'livani',
#  'anshun',
#  "sol'-iletsk",
#  'camayenne',
#  'sambava',
#  'dompu',
#  'barroquinha',
#  'karratha',
#  'kulia village',
#  'goya',
#  'jodhpur',
#  'crane',
#  'basoko',
#  'bakchar',
#  'el nido',
#  'lamu',
#  'nuuk',
#  'mana',
#  'fisterra',
#  'amasra',
#  'solleftea',
#  'geraldton',
#  'port blair',
#  'aldan',
#  'noyabrsk',
#  'rongelap',
#  'constantia',
#  'beni',
#  'ciutadella',
#  'sao vicente',
#  'rockland',
#  'tosontsengel',
#  'la ronge',
#  'playa blanca',
#  "qa'en",
#  'dadonghai',
#  'shimoda',
#  'pola de lena',
#  'suez',
#  'tofol',
#  'tazovsky',
#  'xilin hot',
#  'kangding',
#  'kruisfontein',
#  'nadym',
#  'muli',
#  'kuantan',
#  'vila franca do campo',
#  'san pedro pochutla',
#  'newnham',
#  'charcas',
#  'isla mujeres',
#  'tual',
#  'usinsk',
#  'tindouf',
#  'san andres',
#  'hpa-an',
#  'prado',
#  'taoudenni',
#  'puerto santa',
#  'richards bay',
#  'soure',
#  'rayadrug',
#  'goondiwindi',
#  'hohhot',
#  'sanctuary point',
#  'rabo de peixe',
#  'dubbo',
#  'gaigeturi',
#  'shitanjing',
#  'coxim',
#  'kokuy',
#  'bereznik',
#  'zuni pueblo',
#  "cooper's town",
#  'panaba',
#  'colonia menno',
#  'ujae',
#  'nova sintra',
#  'padangsidempuan',
#  'aripuana',
#  'lovington',
#  'pangody',
#  'salinopolis',
#  'arias',
#  'freeport',
#  'loukhi',
#  'labrador city',
#  "poshekhon'ye",
#  'zhangye',
#  'anna regina',
#  "cherdyn'",
#  'grande prairie',
#  'las khorey',
#  'gantang',
#  "arkhangel'sk",
#  'omaruru',
#  'sinan',
#  'buala',
#  'bata',
#  'kismayo',
#  'brookings',
#  'newman',
#  'gaya',
#  'stephenville',
#  'mata-utu',
#  'sitamau',
#  'mogadishu',
#  'dhidhdhoo',
#  'port shepstone',
#  'batang',
#  'prince rupert',
#  'jerez de la frontera',
#  'edd',
#  'taksimo',
#  'kununurra',
#  'al kharj',
#  'annau',
#  'jwaneng',
#  'labuan',
#  'dondo',
#  'chibougamau',
#  'santana',
#  'holualoa',
#  'acapulco de juarez',
#  'fallon',
#  'maues',
#  'villa presidente frei, nunoa, santiago, chile',
#  'grand-bassam',
#  'mazagao',
#  'okha',
#  "nar'yan-mar",
#  'guiuan']

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %%
#Set api base URL and fill the list of the city_data
city_data = []

#lists for the data frame 
city_weather = []
city_lat = []
city_lng = []     
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

for i, x in enumerate(cities):
    endpoint = f'https://api.openweathermap.org/data/2.5/weather?q={x}&appid={weather_api_key}&units=metric'
    try:
        print(f"{i}. Processing city: {x}")
        city_weather = requests.get(endpoint).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat= city_weather['coord']['lat']
        city_lng= city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": x, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
    except:
        print("City not found. Skipping...")
        pass
    
    
# Indicate that Data Loading is complete 

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# 0. Processing city: adamstown
# 1. Processing city: puerto natales
# 2. Processing city: nola
# 3. Processing city: kodiak
# 4. Processing city: waitangi
# 5. Processing city: punta arenas
# 6. Processing city: port-aux-francais
# 7. Processing city: jamestown
# 8. Processing city: edinburgh of the seven seas
# 9. Processing city: invercargill
# 10. Processing city: petropavlovsk-kamchatsky
# 11. Processing city: enewetak
# 12. Processing city: puerto ayora
# 13. Processing city: port mathurin
# 14. Processing city: remire-montjoly
# 15. Processing city: klyuchi
# 16. Processing city: longyearbyen
# 17. Processing city: pachino
# 18. Processing city: albany
# 19. Processing city: sandnessjoen
# 20. Processing city: talnakh
# 21. Processing city: nogliki
# 22. Processing city: grytviken
# 23. Processing city: atafu village
# 24. Processing city: vanimo
# 25. Processing city: smithers
# 26. Processing city: bethel
# 27. Processing city: sellersburg
# 28. Processing city: san patricio
# 29. Processing city: blackmans bay
# 30. Processing city: katima mulilo
# 31. Processing city: rimouski
# 32. Processing city: kristiansund
# 33. Processing city: cabedelo
# 34. Processing city: arvika
# 35. Processing city: chinchilla
# 36. Processing city: bredasdorp
# 37. Processing city: dawei
# 38. Processing city: amahai
# 39. Processing city: porto novo
# 40. Processing city: ushuaia
# 41. Processing city: pisco
# 42. Processing city: tahe
# 43. Processing city: ciudad lazaro cardenas
# 44. Processing city: avarua
# 45. Processing city: trat
# 46. Processing city: el bauga
# 47. Processing city: pandan
# 48. Processing city: yellowknife
# 49. Processing city: ust-nera
# 50. Processing city: dampit
# 51. Processing city: huetamo de nunez
# 52. Processing city: taiohae
# City not found. Skipping...
# 53. Processing city: margaret river
# 54. Processing city: wakkanai
# 55. Processing city: port saint john's
# 56. Processing city: saipan
# 57. Processing city: tolanaro
# 58. Processing city: mount pearl
# 59. Processing city: puerto aysen
# 60. Processing city: leiston
# 61. Processing city: nyurba
# 62. Processing city: alice springs
# 63. Processing city: kachug
# 64. Processing city: weno
# 65. Processing city: kourou
# 66. Processing city: east london
# 67. Processing city: stanley
# 68. Processing city: dudinka
# 69. Processing city: garoowe
# 70. Processing city: shubarkuduk
# 71. Processing city: keflavik
# 72. Processing city: revda
# 73. Processing city: zemio
# 74. Processing city: yuzhno-kurilsk
# 75. Processing city: hithadhoo
# 76. Processing city: papatowai
# 77. Processing city: carnarvon
# 78. Processing city: forster
# 79. Processing city: santa cruz
# 80. Processing city: olovyannaya
# 81. Processing city: udachny
# 82. Processing city: begamganj
# 83. Processing city: anadyr
# 84. Processing city: hawaiian paradise park
# 85. Processing city: happy valley-goose bay
# 86. Processing city: georgetown
# 87. Processing city: cochrane
# 88. Processing city: villa mercedes
# 89. Processing city: ribeira grande
# 90. Processing city: zaraza
# 91. Processing city: howrah
# 92. Processing city: mejit
# 93. Processing city: hobyo
# 94. Processing city: linxia chengguanzhen
# 95. Processing city: hafar al-batin
# 96. Processing city: touros
# 97. Processing city: karkira
# 98. Processing city: bardai
# 99. Processing city: susuman
# 100. Processing city: ouellah
# City not found. Skipping...
# 101. Processing city: cargados carajos
# City not found. Skipping...
# 102. Processing city: iqaluit
# 103. Processing city: kone
# 104. Processing city: ugoofaaru
# 105. Processing city: miyanoura
# City not found. Skipping...
# 106. Processing city: port dickson
# 107. Processing city: kannangad
# 108. Processing city: port lincoln
# 109. Processing city: sungailiat
# 110. Processing city: road town
# 111. Processing city: wailua homesteads
# 112. Processing city: wynyard
# 113. Processing city: bilibino
# 114. Processing city: shanwei
# 115. Processing city: ilulissat
# 116. Processing city: whitehorse
# 117. Processing city: polyarnyy
# 118. Processing city: puerto san carlos
# City not found. Skipping...
# 119. Processing city: ko pha ngan
# 120. Processing city: tiksi
# 121. Processing city: new norfolk
# 122. Processing city: grand falls-windsor
# 123. Processing city: kresek
# 124. Processing city: sitka
# 125. Processing city: kuqa
# 126. Processing city: alotau
# City not found. Skipping...
# 127. Processing city: borgarnes
# 128. Processing city: isafjordur
# 129. Processing city: temiskaming shores
# 130. Processing city: 'ohonua
# City not found. Skipping...
# 131. Processing city: pont-l'abbe
# City not found. Skipping...
# 132. Processing city: gazojak
# 133. Processing city: codrington
# 134. Processing city: vorgashor
# 135. Processing city: murzuq
# 136. Processing city: itoman
# 137. Processing city: namsos
# 138. Processing city: nouadhibou
# 139. Processing city: mek'ele
# 140. Processing city: ancud
# 141. Processing city: san juan de miraflores
# 142. Processing city: concordia
# 143. Processing city: kingston
# 144. Processing city: nova vicosa
# 145. Processing city: guerrero negro
# 146. Processing city: rumoi
# 147. Processing city: san antonio de pale
# 148. Processing city: castillos
# 149. Processing city: olonkinbyen
# 150. Processing city: qaqortoq
# 151. Processing city: broken hill
# 152. Processing city: port alfred
# 153. Processing city: afaahiti
# 154. Processing city: vadso
# 155. Processing city: devinuwara
# City not found. Skipping...
# 156. Processing city: as sulayyil
# 157. Processing city: west island
# 158. Processing city: malango
# 159. Processing city: flying fish cove
# 160. Processing city: villarrobledo
# 161. Processing city: ust'-kut
# 162. Processing city: taiobeiras
# 163. Processing city: vernon
# 164. Processing city: caleta de carquin
# 165. Processing city: camana
# 166. Processing city: severo-yeniseyskiy
# 167. Processing city: luderitz
# 168. Processing city: oamaru
# 169. Processing city: ibotirama
# 170. Processing city: igrim
# 171. Processing city: faya-largeau
# 172. Processing city: bargaal
# 173. Processing city: badger
# 174. Processing city: sao gabriel da cachoeira
# 175. Processing city: wenxing
# 176. Processing city: mount isa
# 177. Processing city: semnan
# 178. Processing city: pimentel
# 179. Processing city: kuching
# 180. Processing city: freetown
# 181. Processing city: yreka
# 182. Processing city: micheweni
# 183. Processing city: isle of lewis
# City not found. Skipping...
# 184. Processing city: barah
# 185. Processing city: noumea
# 186. Processing city: levuka
# 187. Processing city: piacabucu
# 188. Processing city: mpika
# 189. Processing city: queenstown
# 190. Processing city: belmonte
# 191. Processing city: praia da vitoria
# 192. Processing city: sultanah
# 193. Processing city: puerto baquerizo moreno
# 194. Processing city: vila velha
# 195. Processing city: hermanus
# 196. Processing city: buta
# 197. Processing city: myrina
# 198. Processing city: inirida
# 199. Processing city: margate
# 200. Processing city: melekeok village
# 201. Processing city: oodweyne
# 202. Processing city: lihue
# 203. Processing city: skovorodino
# 204. Processing city: north bend
# 205. Processing city: malita
# 206. Processing city: constitucion
# 207. Processing city: gaspe
# 208. Processing city: fale old settlement
# 209. Processing city: puerto colombia
# 210. Processing city: yarmouth
# 211. Processing city: thompson
# 212. Processing city: salalah
# 213. Processing city: kalmunai
# 214. Processing city: neryungri
# 215. Processing city: dryden
# 216. Processing city: toga village
# City not found. Skipping...
# 217. Processing city: benguela
# 218. Processing city: verkhnevilyuysk
# 219. Processing city: roccella ionica
# 220. Processing city: aykhal
# 221. Processing city: yorkton
# 222. Processing city: anqing
# 223. Processing city: yeniseysk
# 224. Processing city: timoteo
# 225. Processing city: buka
# 226. Processing city: arraial do cabo
# 227. Processing city: casino
# 228. Processing city: lebu
# 229. Processing city: chiredzi
# 230. Processing city: kodinsk
# 231. Processing city: ciudad bolivar
# 232. Processing city: hamilton
# 233. Processing city: ulladulla
# 234. Processing city: la'ie
# 235. Processing city: lensk
# 236. Processing city: novyy turtkul'
# 237. Processing city: kuloy
# 238. Processing city: lejanias
# 239. Processing city: qarazhal
# 240. Processing city: ceeldheer
# 241. Processing city: nordhausen
# 242. Processing city: kindu
# 243. Processing city: tarko-sale
# 244. Processing city: tazacorte
# 245. Processing city: bijie
# 246. Processing city: xindi
# 247. Processing city: bulungu
# 248. Processing city: cumaribo
# City not found. Skipping...
# 249. Processing city: zaozhuang
# 250. Processing city: jamaame
# 251. Processing city: ouarzazat
# 252. Processing city: port elizabeth
# 253. Processing city: knokke
# 254. Processing city: yonggwang-up
# 255. Processing city: utrik
# 256. Processing city: auki
# 257. Processing city: kapa'a
# 258. Processing city: chifeng
# 259. Processing city: cable beach
# City not found. Skipping...
# 260. Processing city: hammerfest
# 261. Processing city: tynda
# 262. Processing city: ytyk-kyuyel'
# City not found. Skipping...
# 263. Processing city: fuxin
# 264. Processing city: port-vila
# 265. Processing city: thunder bay
# 266. Processing city: jiaojiang
# 267. Processing city: cortez
# 268. Processing city: kerikeri
# 269. Processing city: valparaiso
# 270. Processing city: tura
# 271. Processing city: selfoss
# 272. Processing city: dumai
# 273. Processing city: kerema
# 274. Processing city: calama
# 275. Processing city: umag
# 276. Processing city: inhambane
# 277. Processing city: zaragoza
# 278. Processing city: isiolo
# 279. Processing city: akureyri
# 280. Processing city: nacozari de garcia
# 281. Processing city: negombo
# 282. Processing city: fort pierce
# 283. Processing city: robertsport
# 284. Processing city: katsuura
# 285. Processing city: saint-pierre
# 286. Processing city: fomboni
# 287. Processing city: novyy urengoy
# 288. Processing city: carutapera
# 289. Processing city: sinabang
# 290. Processing city: al hilaliyya
# 291. Processing city: fort st. john
# 292. Processing city: fuvahmulah
# City not found. Skipping...
# 293. Processing city: erdenet
# 294. Processing city: landeck
# 295. Processing city: sur
# 296. Processing city: rawson
# 297. Processing city: kidal
# 298. Processing city: sandikli
# 299. Processing city: skowhegan
# 300. Processing city: mizdah
# 301. Processing city: tabuk
# 302. Processing city: canutama
# 303. Processing city: esfarayen
# 304. Processing city: rampachodavaram
# 305. Processing city: reggane
# 306. Processing city: val-d'or
# 307. Processing city: ekibastuz
# 308. Processing city: sechenovo
# 309. Processing city: fort morgan
# 310. Processing city: porto murtinho
# 311. Processing city: wainwright
# 312. Processing city: puerto cabezas
# 313. Processing city: st. john's
# 314. Processing city: mahajanga
# 315. Processing city: rethymno
# 316. Processing city: dalbandin
# 317. Processing city: cabo san lucas
# 318. Processing city: talara
# 319. Processing city: palikir - national government center
# 320. Processing city: argo
# 321. Processing city: uturoa
# 322. Processing city: sassandra
# 323. Processing city: khorixas
# 324. Processing city: nishinoomote
# 325. Processing city: correntina
# 326. Processing city: commentry
# 327. Processing city: plettenberg bay
# 328. Processing city: traralgon
# 329. Processing city: chela
# 330. Processing city: haenam
# 331. Processing city: oranjemund
# 332. Processing city: parkersburg
# 333. Processing city: carauari
# 334. Processing city: butterworth
# 335. Processing city: rio grande
# 336. Processing city: kaifeng
# 337. Processing city: shalqar
# 338. Processing city: kampene
# 339. Processing city: aasiaat
# 340. Processing city: sierra grande
# 341. Processing city: villa gesell
# 342. Processing city: rawai
# 343. Processing city: baluntaicun
# City not found. Skipping...
# 344. Processing city: ust'-talovka
# 345. Processing city: minot
# 346. Processing city: mili
# 347. Processing city: dingwall
# 348. Processing city: astrakhan
# 349. Processing city: dalandzadgad
# 350. Processing city: kankaanpaa
# 351. Processing city: namibe
# 352. Processing city: kargasok
# 353. Processing city: yerofey pavlovich
# 354. Processing city: nyandoma
# 355. Processing city: dien bien phu
# 356. Processing city: sao jose da coroa grande
# 357. Processing city: coahuayana de hidalgo
# 358. Processing city: solnechnyy
# 359. Processing city: al kharijah
# 360. Processing city: filadelfia
# 361. Processing city: guatrache
# 362. Processing city: saint-francois
# 363. Processing city: penafiel
# 364. Processing city: gebeit
# 365. Processing city: tranovaho
# City not found. Skipping...
# 366. Processing city: san jose village
# City not found. Skipping...
# 367. Processing city: picos
# 368. Processing city: khandyga
# 369. Processing city: popondetta
# 370. Processing city: panghyon-dong
# 371. Processing city: vilyuchinsk
# 372. Processing city: anibare
# City not found. Skipping...
# 373. Processing city: male
# 374. Processing city: yokadouma
# 375. Processing city: juan griego
# 376. Processing city: quezon
# 377. Processing city: tralee
# 378. Processing city: champerico
# 379. Processing city: saint-philippe
# 380. Processing city: coquimbo
# 381. Processing city: usogorsk
# 382. Processing city: viedma
# 383. Processing city: rakops
# 384. Processing city: chonchi
# 385. Processing city: lompoc
# 386. Processing city: butwal
# 387. Processing city: portland
# 388. Processing city: kolobrzeg
# 389. Processing city: govindgarh
# 390. Processing city: minab
# 391. Processing city: ola
# 392. Processing city: college
# 393. Processing city: markovo
# 394. Processing city: hotan
# 395. Processing city: konstantinovka
# 396. Processing city: kiuruvesi
# 397. Processing city: ghat
# 398. Processing city: kokologo
# 399. Processing city: miguel ahumada
# 400. Processing city: pitiquito
# 401. Processing city: arafat
# 402. Processing city: al jawf
# 403. Processing city: urucara
# 404. Processing city: pathein
# 405. Processing city: santa croce camerina
# 406. Processing city: egilsstadir
# 407. Processing city: shklow
# 408. Processing city: alofi
# 409. Processing city: hirara
# 410. Processing city: hargeysa
# 411. Processing city: smara
# 412. Processing city: burnie
# 413. Processing city: saurimo
# 414. Processing city: phnom penh
# 415. Processing city: mhangura
# 416. Processing city: suva
# 417. Processing city: sinhyeon
# 418. Processing city: shahrak
# 419. Processing city: isangel
# 420. Processing city: ta`u
# 421. Processing city: colonia
# 422. Processing city: chernomorskoye
# 423. Processing city: aberdeen
# 424. Processing city: jacksonville
# 425. Processing city: inhumas
# 426. Processing city: westport
# 427. Processing city: dongola
# 428. Processing city: pacific grove
# 429. Processing city: tongchuanshi
# 430. Processing city: kultali
# City not found. Skipping...
# 431. Processing city: minas de marcona
# 432. Processing city: san julian
# 433. Processing city: palmer
# 434. Processing city: howard springs
# 435. Processing city: bayanhongor
# 436. Processing city: saldanha
# 437. Processing city: la sarre
# 438. Processing city: semey
# 439. Processing city: port douglas
# 440. Processing city: hadibu
# 441. Processing city: lazaro cardenas
# 442. Processing city: takamaka
# City not found. Skipping...
# 443. Processing city: baykal'sk
# 444. Processing city: kill devil hills
# 445. Processing city: livani
# 446. Processing city: anshun
# 447. Processing city: sol'-iletsk
# 448. Processing city: camayenne
# 449. Processing city: sambava
# 450. Processing city: dompu
# 451. Processing city: barroquinha
# 452. Processing city: karratha
# 453. Processing city: kulia village
# City not found. Skipping...
# 454. Processing city: goya
# 455. Processing city: jodhpur
# 456. Processing city: crane
# 457. Processing city: basoko
# 458. Processing city: bakchar
# 459. Processing city: el nido
# 460. Processing city: lamu
# 461. Processing city: nuuk
# 462. Processing city: mana
# 463. Processing city: fisterra
# 464. Processing city: amasra
# 465. Processing city: solleftea
# 466. Processing city: geraldton
# 467. Processing city: port blair
# 468. Processing city: aldan
# 469. Processing city: noyabrsk
# 470. Processing city: rongelap
# 471. Processing city: constantia
# 472. Processing city: beni
# 473. Processing city: ciutadella
# 474. Processing city: sao vicente
# 475. Processing city: rockland
# 476. Processing city: tosontsengel
# 477. Processing city: la ronge
# 478. Processing city: playa blanca
# 479. Processing city: qa'en
# 480. Processing city: dadonghai
# City not found. Skipping...
# 481. Processing city: shimoda
# 482. Processing city: pola de lena
# 483. Processing city: suez
# 484. Processing city: tofol
# 485. Processing city: tazovsky
# 486. Processing city: xilin hot
# 487. Processing city: kangding
# 488. Processing city: kruisfontein
# 489. Processing city: nadym
# 490. Processing city: muli
# 491. Processing city: kuantan
# 492. Processing city: vila franca do campo
# 493. Processing city: san pedro pochutla
# 494. Processing city: newnham
# 495. Processing city: charcas
# 496. Processing city: isla mujeres
# 497. Processing city: tual
# 498. Processing city: usinsk
# 499. Processing city: tindouf
# 500. Processing city: san andres
# 501. Processing city: hpa-an
# 502. Processing city: prado
# 503. Processing city: taoudenni
# 504. Processing city: puerto santa
# 505. Processing city: richards bay
# 506. Processing city: soure
# 507. Processing city: rayadrug
# 508. Processing city: goondiwindi
# 509. Processing city: hohhot
# 510. Processing city: sanctuary point
# 511. Processing city: rabo de peixe
# 512. Processing city: dubbo
# 513. Processing city: gaigeturi
# 514. Processing city: shitanjing
# 515. Processing city: coxim
# 516. Processing city: kokuy
# 517. Processing city: bereznik
# 518. Processing city: zuni pueblo
# 519. Processing city: cooper's town
# 520. Processing city: panaba
# 521. Processing city: colonia menno
# 522. Processing city: ujae
# 523. Processing city: nova sintra
# 524. Processing city: padangsidempuan
# 525. Processing city: aripuana
# 526. Processing city: lovington
# 527. Processing city: pangody
# 528. Processing city: salinopolis
# 529. Processing city: arias
# 530. Processing city: freeport
# 531. Processing city: loukhi
# 532. Processing city: labrador city
# 533. Processing city: poshekhon'ye
# 534. Processing city: zhangye
# 535. Processing city: anna regina
# 536. Processing city: cherdyn'
# 537. Processing city: grande prairie
# 538. Processing city: las khorey
# 539. Processing city: gantang
# 540. Processing city: arkhangel'sk
# 541. Processing city: omaruru
# 542. Processing city: sinan
# 543. Processing city: buala
# 544. Processing city: bata
# 545. Processing city: kismayo
# 546. Processing city: brookings
# 547. Processing city: newman
# 548. Processing city: gaya
# 549. Processing city: stephenville
# 550. Processing city: mata-utu
# 551. Processing city: sitamau
# 552. Processing city: mogadishu
# 553. Processing city: dhidhdhoo
# 554. Processing city: port shepstone
# 555. Processing city: batang
# 556. Processing city: prince rupert
# 557. Processing city: jerez de la frontera
# 558. Processing city: edd
# 559. Processing city: taksimo
# 560. Processing city: kununurra
# 561. Processing city: al kharj
# 562. Processing city: annau
# 563. Processing city: jwaneng
# 564. Processing city: labuan
# 565. Processing city: dondo
# 566. Processing city: chibougamau
# 567. Processing city: santana
# 568. Processing city: holualoa
# 569. Processing city: acapulco de juarez
# 570. Processing city: fallon
# 571. Processing city: maues
# 572. Processing city: villa presidente frei, nunoa, santiago, chile
# City not found. Skipping...
# 573. Processing city: grand-bassam
# 574. Processing city: mazagao
# 575. Processing city: okha
# 576. Processing city: nar'yan-mar
# 577. Processing city: guiuan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert city_data to a Pandas data frame 

city_data_df = pd.DataFrame(city_data)

#Show the count 
city_data_df.count()
#city_weather
# Out:
# City          554
# Lat           554
# Lng           554
# Max Temp      554
# Humidity      554
# Cloudiness    554
# Wind Speed    554
# Country       554
# Date          554
# dtype: int64

# %%
# Display sample data
city_data_df.head()
#city_data
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       adamstown -25.0660 -130.1015     22.38        78         100
# 1  puerto natales -51.7236  -72.4875      7.31        72           9
# 2            nola  40.9220   14.5329     17.57        85           2
# 3          kodiak  57.7900 -152.4072      5.73        81         100
# 4        waitangi -43.9535 -176.5597     15.46        93         100
#
#    Wind Speed Country        Date
# 0        3.88      PN  1683408182
# 1        3.78      CL  1683408182
# 2        0.75      IT  1683408183
# 3        3.09      US  1683408270
# 4        1.79      NZ  1683408270

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
#Read csv
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

#data display
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             adamstown -25.0660 -130.1015     22.38        78         100
# 1        puerto natales -51.7236  -72.4875      7.31        72           9
# 2                  nola  40.9220   14.5329     17.57        85           2
# 3                kodiak  57.7900 -152.4072      5.73        81         100
# 4              waitangi -43.9535 -176.5597     15.46        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.88      PN  1683408182
# 1              3.78      CL  1683408182
# 2              0.75      IT  1683408183
# 3              3.09      US  1683408270
# 4              1.79      NZ  1683408270

# %% [markdown]
# # Scatter plots

# %% [markdown]
# ## Latitude Vs Temperature

# %%
#scatter
x= city_data_df['Lat']
y= city_data_df['Max Temp']
plt.scatter(x,y, edgecolors='black')
#Format 
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

#save the figure
plt.savefig("output_data/Fig1.png")

plt.show()

# %% [markdown]
# ## Latitude Vs. Humidity

# %%
#scatter
y= city_data_df['Humidity']
plt.scatter(x,y, edgecolors='black')
#Format 
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

#save the figure
plt.savefig("output_data/Fig2.png")


plt.show()

# %% [markdown]
# ## Latitude Vs. Cloudiness

# %%
#scatter
y= city_data_df['Cloudiness']
plt.scatter(x,y, edgecolors='black')
#Format 
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

#save the figure
plt.savefig("output_data/Fig3.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed

# %%
#scatter
y= city_data_df['Wind Speed']
plt.scatter(x,y, edgecolors='black')
#Format 
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

#save the figure
plt.savefig("output_data/Fig4.png")

plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship

# %% [markdown]
# ### Defining a function for the linear regresseion
#
# $$y = b_0 + b_1 * Latitude $$

# %%
#remane the lat column for plotting 
city_data_df = city_data_df.rename(columns={'Lat':'Latitude'})
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Latitude'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City  Latitude       Lng  Max Temp  Humidity  \
# City_ID
# 2                            nola   40.9220   14.5329     17.57        85
# 3                          kodiak   57.7900 -152.4072      5.73        81
# 7                       jamestown   42.0970  -79.2353     18.80        45
# 10       petropavlovsk-kamchatsky   53.0452  158.6483      4.33        56
# 11                       enewetak   11.3474  162.3373     27.42        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 2        0.75      IT  1683408183
# 3               100        3.09      US  1683408270
# 7                 0        3.60      US  1683407975
# 10               40        7.00      RU  1683408273
# 11               90        8.07      MH  1683408072

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Latitude'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City  Latitude       Lng  Max Temp  Humidity  \
# City_ID
# 0                adamstown  -25.0660 -130.1015     22.38        78
# 1           puerto natales  -51.7236  -72.4875      7.31        72
# 4                 waitangi  -43.9535 -176.5597     15.46        93
# 5             punta arenas  -53.1500  -70.9167      8.06        71
# 6        port-aux-francais  -49.3500   70.2167      4.36        60
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.88      PN  1683408182
# 1                 9        3.78      CL  1683408182
# 4               100        1.79      NZ  1683408270
# 5                20        7.72      CL  1683408271
# 6                77       13.22      TF  1683408271

# %% [markdown]
# ##  Temperature vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
#Lineal regression 
x=northern_hemi_df['Latitude']
y=northern_hemi_df['Max Temp']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)

#Y value predictions
y_predict = intercept + (slope*x)

#Scatter 
northern_hemi_df.plot(kind='scatter',x='Latitude',y='Max Temp')
#add the line to the scatter
plt.plot(x,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (5,-10), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: -0.8374533134021283

# %%
#Southern Hemisphere
#Lineal regression 
xs=southern_hemi_df['Latitude']
y=southern_hemi_df['Max Temp']

slope, intercept, rvalue, pvalue, stderr = linregress(xs,y)

#Y value predictions
y_predict = intercept + (slope*xs)

#Scatter 
southern_hemi_df.plot(kind='scatter',x='Latitude',y='Max Temp')
#add the line to the scatter
plt.plot(xs,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (-50,25), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.8279227110108236

# %% [markdown]
# ### Discussion about the linear relationship:
# In the first plot, we can see that the two variables have a strong correlation because when the latitude increases the Max temperature decreases, and the r-value at -.83 confirms this strong negative correlation. In the second plot, we can observe a clear positive correlation between the variables because both variables increase together almost to simulate a "perfect correlation". In conclusion with the linear relationship we can expect that as the latitude is closer to 0, the Max Temperature will be higher

# %% [markdown]
# ## Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
#Lineal regression 
x=northern_hemi_df['Latitude']
y=northern_hemi_df['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)

#Y value predictions
y_predict = intercept + (slope*x)

#Scatter 
northern_hemi_df.plot(kind='scatter',x='Latitude',y='Humidity')
#add the line to the scatter
plt.plot(x,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (50,20), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.05089306361217108

# %%
#Southern Hemisphere
#Lineal regression 
xs=southern_hemi_df['Latitude']
y=southern_hemi_df['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(xs,y)

#Y value predictions
y_predict = intercept + (slope*xs)

#Scatter 
southern_hemi_df.plot(kind='scatter',x='Latitude',y='Humidity')
#add the line to the scatter
plt.plot(xs,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (-50,25), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.08559177350530082

# %% [markdown]
# ### Discussion about the linear relationship:
# According to the r-values of the plots above, the correlation between the latitude and the humidity is poor as they both are near to 0. The linear regression does not help in the prediction of the humidity base on the change in latitude. In the plots, we can see that most of the cities have high levels of humidity but these levels do not depend on the latitude.

# %% [markdown]
# ## Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
#Lineal regression 
x=northern_hemi_df['Latitude']
y=northern_hemi_df['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)

#Y value predictions
y_predict = intercept + (slope*x)

#Scatter 
northern_hemi_df.plot(kind='scatter',x='Latitude',y='Cloudiness')
#add the line to the scatter
plt.plot(x,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (40,25), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.03571140494733467

# %%
#Southern Hemisphere
#Lineal regression 
xs=southern_hemi_df['Latitude']
y=southern_hemi_df['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(xs,y)

#Y value predictions
y_predict = intercept + (slope*xs)

#Scatter 
southern_hemi_df.plot(kind='scatter',x='Latitude',y='Cloudiness')
#add the line to the scatter
plt.plot(xs,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (-50,25), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: -0.031098872839129394

# %% [markdown]
# ### Discussion about the linear relationship:
# We can see that the slope in the line of both plots is almost 0 which indicates that they have a small change rate, this makes sense because the correlation coefficient is near to 0, so there is no relation between the variables and we can´t estimate the cloudiness of a city depending on the latitude of the city. The plots show that the city's percentage of cloudiness is concentrated at the edges, meaning the information looks like is biased towards 0% or 100%.

# %% [markdown]
# ## Wind Speed vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
#Lineal regression 
x=northern_hemi_df['Latitude']
y=northern_hemi_df['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)

#Y value predictions
y_predict = intercept + (slope*x)

#Scatter 
northern_hemi_df.plot(kind='scatter',x='Latitude',y='Wind Speed')
#add the line to the scatter
plt.plot(x,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (10,12), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: -0.10808658641504763

# %%
#Southern Hemisphere
#Lineal regression 
xs=southern_hemi_df['Latitude']
y=southern_hemi_df['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(xs,y)

#Y value predictions
y_predict = intercept + (slope*xs)

#Scatter 
southern_hemi_df.plot(kind='scatter',x='Latitude',y='Wind Speed')
#add the line to the scatter
plt.plot(xs,y_predict,color='r')
#add the ecuation 
line = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.annotate(line, (-50,12), color = 'r', fontsize = 15)
#r-value
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: -0.16720303051887728

# %% [markdown]
# ### Discussion about the linear relationship:
# Even though the correlation between the wind speed and the latitude is greater than the latitude vs cloudiness and the humidity vs latitude, it is still very low. Doing a prediction on the wind speed based on the lineal regression wouldn´t be certain, in both plots the correlation is negative which means that if the latitude increases the wind speed may decrease, but as we see in the graph, there are no obvious visual signs that this is true.
